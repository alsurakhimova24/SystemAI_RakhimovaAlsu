# %% [markdown]
# # Практическая работа №3
# ## Тема: «Визуализация данных»
# ### Выполнила студентка: Рахимова Алсу ПКТб-21-1
# #### ВАРИАНТ: 16

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# #### Задание 1. Загрузить и данные из файла Dataset_Variants.xlsx, где номер листа - ваш вариант

# %%
df=pd.read_excel('Dataset_Variants.xlsx',sheet_name='16')

# %% [markdown]
# #### Задание 2. Отобразить данные вашего варианта

# %%
print('Данные 16 варианта: ')
df
# Out:
# Данные 16 варианта:
#      X           Y
# 0    1   30.659766
# 1    2   57.427815
# 2    3   70.397238
# 3    4   75.220629
# 4    5   70.713657
# 5    6   44.579014
# 6    7   42.221660
# 7    8   80.725687
# 8    9   49.186116
# 9   10   63.072935
# 10  11   62.736450
# 11  12   27.946345
# 12  13  118.888767
# 13  14   26.767469
# 14  15   54.387630
# 15  16  110.262209
# 16  17    5.425210
# 17  18   83.537845
# 18  19   10.336140
# 19  20   40.213439
# 20  21   -7.218131
# 21  22   80.286799
# 22  23   51.179473
# 23  24   62.406588
# 24  25   39.950680
# 25  26   74.311532
# 26  27   41.853485
# 27  28   23.506021
# 28  29   57.112590
# 29  30   73.927782
# 30  31   80.438741
# 31  32   38.776068
# 32  33   21.374734
# 33  34   65.922637
# 34  35   97.303274
# 35  36   84.547952
# 36  37   21.400484
# 37  38  106.806130
# 38  39   37.530657
# 39  40   70.107791
# 40  41   32.696352
# 41  42   67.335253
# 42  43   72.294614
# 43  44  104.404609
# 44  45   43.050551
# 45  46    6.884722
# 46  47   66.311105
# 47  48   36.616899
# 48  49   64.520651
# 49  50   63.962790

# %% [markdown]
# #### Задание 3. Визуализировать данные в стиле Столбчатые диаграммы (подписать оси)

# %%
X = df['X']
Y = df['Y']
plt.bar(X, Y)
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %% [markdown]
# #### Задание 4. Визуализировать данные в стиле Точечный график (подписать оси)

# %%
plt.scatter(X, Y)
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %% [markdown]
# #### Задание 5. Отрицательные значения по Y заменить значением по модулю

# %%
df['Y'] = df['Y'].abs()
df.to_excel('New_Dataset_Variants.xlsx', index = False)

# %% [markdown]
# #### Задание 6. Отобразить изменённые данные вашего варианта

# %%
df1=pd.read_excel('New_Dataset_Variants.xlsx',sheet_name='Sheet1')
df1
# Out:
#      X           Y
# 0    1   30.659766
# 1    2   57.427815
# 2    3   70.397238
# 3    4   75.220629
# 4    5   70.713657
# 5    6   44.579014
# 6    7   42.221660
# 7    8   80.725687
# 8    9   49.186116
# 9   10   63.072935
# 10  11   62.736450
# 11  12   27.946345
# 12  13  118.888767
# 13  14   26.767469
# 14  15   54.387630
# 15  16  110.262209
# 16  17    5.425210
# 17  18   83.537845
# 18  19   10.336140
# 19  20   40.213439
# 20  21    7.218131
# 21  22   80.286799
# 22  23   51.179473
# 23  24   62.406588
# 24  25   39.950680
# 25  26   74.311532
# 26  27   41.853485
# 27  28   23.506021
# 28  29   57.112590
# 29  30   73.927782
# 30  31   80.438741
# 31  32   38.776068
# 32  33   21.374734
# 33  34   65.922637
# 34  35   97.303274
# 35  36   84.547952
# 36  37   21.400484
# 37  38  106.806130
# 38  39   37.530657
# 39  40   70.107791
# 40  41   32.696352
# 41  42   67.335253
# 42  43   72.294614
# 43  44  104.404609
# 44  45   43.050551
# 45  46    6.884722
# 46  47   66.311105
# 47  48   36.616899
# 48  49   64.520651
# 49  50   63.962790

# %% [markdown]
# #### Задание 7. Визуализировать изменённые данные вашего варианта в стиле Столбчатые диаграммы (подписать оси, столбцы зеленого цвета)

# %%
X = df1['X']
Y = df1['Y']
plt.bar(X, Y, color = 'green')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %% [markdown]
# #### Задание 8. Визуализировать изменённые данные вашего варианта в стиле Точечный график (подписать оси, столбцы зеленого цвета)

# %%
plt.scatter(X, Y, color = 'green')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %% [markdown]
# #### Задание 9. Визуализировать изменённые данные вашего варианта в стиле Линейный график (подписать оси, цвет, стиль линии изменить на ваше усмотрение)

# %%
plt.plot(X, Y, '--r')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %% [markdown]
# #### Задание 10. Визуализировать изменённые данные вашего варианта в стиле Линейный график с маркером (подписать оси, цвет, стиль линии и тип маркера изменить на ваше усмотрение)

# %%
plt.plot(X, Y, marker='o',c = 'y')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %% [markdown]
# #### Задание 11. Визуализировать изменённые данные вашего варианта в стиле Цветовое распределение

# %%
plt.pcolor(df1)
plt.colorbar()

# %% [markdown]
# #### Задание 12. Загрузить данные из файла Dataset_Variants.xlsx c номером листа 10000, где номер столбца Y ваш вариант

# %%
df2=pd.read_excel('Dataset_Variants.xlsx',sheet_name='10000')

# %% [markdown]
# #### Задание 13. Отобразить данные вашего варианта

# %%
my_column=df2[['X','Y16']]
my_column
# Out:
#           X          Y16
# 0         1  1053.351414
# 1         2  1031.709874
# 2         3  1032.076628
# 3         4  1046.193691
# 4         5  1026.658881
# ...     ...          ...
# 9995   9996  1008.880193
# 9996   9997   993.078404
# 9997   9998  1026.886198
# 9998   9999   985.463489
# 9999  10000  1009.891949
#
# [10000 rows x 2 columns]

# %% [markdown]
# #### Задание 14. Визуализировать данные в стиле Столбчатые диаграммы (подписать оси)

# %%
X = my_column['X']
Y = my_column['Y16']
plt.bar(X, Y)
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %% [markdown]
# #### Задание 15. Визуализировать данные в стиле Точечный график (подписать оси)

# %%
plt.scatter(X, Y)
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %% [markdown]
# #### Задание 16. Визуализировать данные вашего варианта в стиле Столбчатые диаграммы (подписать оси, столбцы зеленого цвета)

# %%
X = my_column['X']
Y = my_column['Y16']
plt.bar(X, Y, color = 'green')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %% [markdown]
# #### Задание 17. Визуализировать данные вашего варианта в стиле Точечный график (подписать оси, столбцы красного цвета)

# %%
plt.scatter(X, Y, color = 'green')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %% [markdown]
# #### Задание 18. Визуализировать данные вашего варианта в стиле Линейный график (подписать оси, цвет, стиль линии изменить на ваше усмотрение)

# %%
plt.plot(X, Y, ':y')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %% [markdown]
# #### Задание 19. Визуализировать данные вашего варианта в стиле Цветовое распределение

# %%
plt.pcolor(my_column)
plt.colorbar()

# %% [markdown]
# #### Задание 20. Загрузить данные из вашего скаченного DataSet

# %%
df3=pd.read_excel('ChocolateBarRatings.xlsx',sheet_name='flavors_of_cacao')

# %% [markdown]
# #### Задание 21. Отобразить данные вашего скаченного DataSet

# %%
df3
# Out:
#       Company (Maker-if known) Specific Bean Originor Bar Name     REF  \
# 0                     A. Morin                     Agua Grande  1876.0
# 1                     A. Morin                           Kpime  1676.0
# 2                     A. Morin                          Atsane     NaN
# 3                     A. Morin                           Akata     NaN
# 4                     A. Morin                          Quilla  1704.0
# ...                        ...                             ...     ...
# 14355                   Zotter                            Peru   647.0
# 14356                   Zotter                           Congo   749.0
# 14357                   Zotter                    Kerala State   749.0
# 14358                   Zotter                    Kerala State   781.0
# 14359                   Zotter              Brazil, Mitzi Blue   486.0
#
#        ReviewDate Cocoa Percent CompanyLocation  Rating   BeanType  \
# 0             NaN          0.63          France    3.75    Criollo
# 1          2015.0           0.7          France    2.75    Criollo
# 2          2015.0           0.7          France     NaN    Criollo
# 3             NaN           0.7          France    3.00    Criollo
# 4             NaN           0.7          France     NaN    Criollo
# ...           ...           ...             ...     ...        ...
# 14355      2011.0           0.7         Austria    2.00    Criollo
# 14356      2011.0          0.65         Austria    3.00  Forastero
# 14357      2011.0          0.65         Austria    3.50  Forastero
# 14358      2011.0          0.62         Austria    2.00    Criollo
# 14359      2010.0          0.65         Austria    2.75    Criollo
#
#       Broad BeanOrigin
# 0             Sao Tome
# 1                 Togo
# 2                 Togo
# 3                 Togo
# 4                 Peru
# ...                ...
# 14355             Peru
# 14356            Congo
# 14357            India
# 14358            India
# 14359           Brazil
#
# [14360 rows x 9 columns]

# %% [markdown]
# #### Задание 22. Визуализировать данные вашего скаченного DataSet в стиле Столбчатые диаграммы (подписать оси, заголовок)

# %%
ref = df3['REF']
rating = df3['Rating']
plt.bar(ref, rating)
plt.xlabel('REF')
plt.ylabel('Рейтинг')
plt.title('Рейтинг шоколадных батончиков', fontsize=17)
plt.show()

# %% [markdown]
# #### Задание 23. Визуализировать данные вашего скаченного DataSet в стиле Точечный график (подписать оси, заголовок)

# %%
plt.scatter(ref, rating)
plt.xlabel('REF')
plt.ylabel('Рейтинг')
plt.title('Рейтинг шоколадных батончиков', fontsize=17)
plt.show()

# %% [markdown]
# #### Задание 24. Визуализировать данные вашего скаченного DataSet в стиле Столбчатые диаграммы (подписать оси, заголовок, столбцы зеленого цвета)

# %%
ref = df3['REF']
rating = df3['Rating']
plt.bar(ref, rating, color = 'green')
plt.xlabel('REF')
plt.ylabel('Рейтинг')
plt.title('Рейтинг шоколадных батончиков', fontsize=17)
plt.show()

# %% [markdown]
# #### Задание 25. Визуализировать изменённые данные вашего варианта в стиле Точечный график (подписать оси, заголовок, столбцы красного цвета)

# %%
plt.scatter(ref, rating, color = 'red')
plt.xlabel('REF')
plt.ylabel('Рейтинг')
plt.title('Рейтинг шоколадных батончиков', fontsize=17)
plt.show()

# %% [markdown]
# #### Задание 26. Визуализировать данные вашего скаченного DataSet в стиле Линейный график (подписать оси, заголовок, цвет, стиль линии изменить на ваше усмотрение)

# %%
plt.plot(ref, rating, '-.', color = 'pink')
plt.xlabel('REF')
plt.ylabel('Рейтинг')
plt.title('Рейтинг шоколадных батончиков', fontsize=17)
plt.show()

# %% [markdown]
# #### Задание 27. Визуализировать данные вашего скаченного DataSet в стиле Цветовое распределение

# %%
a=df3[['REF','Rating']]
plt.pcolor(a)
plt.colorbar()
