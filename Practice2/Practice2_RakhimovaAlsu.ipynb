# %% [markdown]
# # Практическая работа №2
# ## Тема: «Предобработка данных в Pandas»
# ### Выполнила студентка: Рахимова Алсу ПКТб-21-1
# #### ВАРИАНТ: 16

# %% [markdown]
# #### Задание 1. Создать Series s1 и s2 по картинке
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
import pandas as pd
import numpy as np

# %%
s1=pd.Series([3,2,0,1], name = 'apples')

# %%
s1
# Out:
# 0    3
# 1    2
# 2    0
# 3    1
# Name: apples, dtype: int64

# %%
s2=pd.Series([0,3,7,2], name = 'oranges')

# %%
s2
# Out:
# 0    0
# 1    3
# 2    7
# 3    2
# Name: oranges, dtype: int64

# %% [markdown]
# #### Задание 2. Создать DataFrame df1 по картинке
# ![image.png](attachment:image.png)

# %%
pd.concat([s1,s2], axis = 1)
# Out:
#    apples  oranges
# 0       3        0
# 1       2        3
# 2       0        7
# 3       1        2

# %% [markdown]
# # Описание DataSet

# %% [markdown]
# Экспертный рейтинг более 14000 шоколадных батончиков. В нём указаны компания-производитель, конкретное происхождение бобов либо название батончика, количество отданных голосов за конкретную марку, год проведения опроса, процент содержания какао, местонахождение компании-производителя, рейтинг от 1 до 5 и тип какао-бобов.

# %% [markdown]
# #### Задание 3. Загрузить ваш DataSet

# %%
import pandas as pd

# %%
df=pd.read_excel('ChocolateBarRatings.xlsx',sheet_name='flavors_of_cacao')

# %%
df
# Out:
#       Company (Maker-if known) Specific Bean Originor Bar Name     REF  \
# 0                     A. Morin                     Agua Grande  1876.0
# 1                     A. Morin                           Kpime  1676.0
# 2                     A. Morin                          Atsane     NaN
# 3                     A. Morin                           Akata     NaN
# 4                     A. Morin                          Quilla  1704.0
# ...                        ...                             ...     ...
# 14355                   Zotter                            Peru   647.0
# 14356                   Zotter                           Congo   749.0
# 14357                   Zotter                    Kerala State   749.0
# 14358                   Zotter                    Kerala State   781.0
# 14359                   Zotter              Brazil, Mitzi Blue   486.0
#
#        ReviewDate Cocoa Percent CompanyLocation  Rating   BeanType  \
# 0             NaN          0.63          France    3.75    Criollo
# 1          2015.0           0.7          France    2.75    Criollo
# 2          2015.0           0.7          France     NaN    Criollo
# 3             NaN           0.7          France    3.00    Criollo
# 4             NaN           0.7          France     NaN    Criollo
# ...           ...           ...             ...     ...        ...
# 14355      2011.0           0.7         Austria    2.00    Criollo
# 14356      2011.0          0.65         Austria    3.00  Forastero
# 14357      2011.0          0.65         Austria    3.50  Forastero
# 14358      2011.0          0.62         Austria    2.00    Criollo
# 14359      2010.0          0.65         Austria    2.75    Criollo
#
#       Broad BeanOrigin
# 0             Sao Tome
# 1                 Togo
# 2                 Togo
# 3                 Togo
# 4                 Peru
# ...                ...
# 14355             Peru
# 14356            Congo
# 14357            India
# 14358            India
# 14359           Brazil
#
# [14360 rows x 9 columns]

# %% [markdown]
# #### Задание 4. Показать первые 10 записей вашего DataFrame

# %%
df.head(10)
# Out:
#   Company (Maker-if known) Specific Bean Originor Bar Name     REF  \
# 0                 A. Morin                     Agua Grande  1876.0
# 1                 A. Morin                           Kpime  1676.0
# 2                 A. Morin                          Atsane     NaN
# 3                 A. Morin                           Akata     NaN
# 4                 A. Morin                          Quilla  1704.0
# 5                 A. Morin                        Carenero  1315.0
# 6                 A. Morin                            Cuba  1315.0
# 7                 A. Morin                    Sur del Lago  1315.0
# 8                 A. Morin                  Puerto Cabello  1319.0
# 9                 A. Morin                         Pablino  1319.0
#
#    ReviewDate Cocoa Percent CompanyLocation  Rating BeanType Broad BeanOrigin
# 0         NaN          0.63          France    3.75  Criollo         Sao Tome
# 1      2015.0           0.7          France    2.75  Criollo             Togo
# 2      2015.0           0.7          France     NaN  Criollo             Togo
# 3         NaN           0.7          France    3.00  Criollo             Togo
# 4         NaN           0.7          France     NaN  Criollo             Peru
# 5      2014.0           0.7          France    3.50  Criollo        Venezuela
# 6      2014.0           0.7          France     NaN  Criollo             Cuba
# 7      2014.0           0.7          France     NaN  Criollo        Venezuela
# 8      2014.0           0.7          France     NaN  Criollo        Venezuela
# 9      2014.0           0.7          France     NaN  Criollo             Peru

# %% [markdown]
# #### Задание 5. Показать последние 10 записей вашего DataFrame

# %%
df.tail(10)
# Out:
#       Company (Maker-if known) Specific Bean Originor Bar Name    REF  \
# 14350                   Zotter                    Huiwani Coop    NaN
# 14351                   Zotter                   El Ceibo Coop  879.0
# 14352                   Zotter                   Santo Domingo  879.0
# 14353                   Zotter                Kongo, Highlands  883.0
# 14354                   Zotter                   Indianer, Raw  883.0
# 14355                   Zotter                            Peru  647.0
# 14356                   Zotter                           Congo  749.0
# 14357                   Zotter                    Kerala State  749.0
# 14358                   Zotter                    Kerala State  781.0
# 14359                   Zotter              Brazil, Mitzi Blue  486.0
#
#        ReviewDate Cocoa Percent CompanyLocation  Rating             BeanType  \
# 14350      2012.0          0.75         Austria    2.75  Criollo, Trinitario
# 14351      2012.0           0.9         Austria    3.00              Criollo
# 14352      2012.0           0.7         Austria    3.00              Criollo
# 14353      2012.0          0.68         Austria    3.00            Forastero
# 14354      2012.0          0.58         Austria    3.50              Criollo
# 14355      2011.0           0.7         Austria    2.00              Criollo
# 14356      2011.0          0.65         Austria    3.00            Forastero
# 14357      2011.0          0.65         Austria    3.50            Forastero
# 14358      2011.0          0.62         Austria    2.00              Criollo
# 14359      2010.0          0.65         Austria    2.75              Criollo
#
#          Broad BeanOrigin
# 14350    Papua New Guinea
# 14351             Bolivia
# 14352  Dominican Republic
# 14353               Congo
# 14354             Bolivia
# 14355                Peru
# 14356               Congo
# 14357               India
# 14358               India
# 14359              Brazil

# %% [markdown]
# #### Задание 6. Показать случайные 10 строк из вашего DataFrame

# %%
df.sample(10)
# Out:
#       Company (Maker-if known)   Specific Bean Originor Bar Name     REF  \
# 87                      Amedei                     Toscano Black    75.0
# 6849                    Sirene                 Kokoa Kamili Coop  1856.0
# 3822                    Bonnat          Madagascar, 100% criollo   629.0
# 10418         Scharffen Berger                         Semisweet    56.0
# 1505                  Solstice                        San Martin  1161.0
# 10510                     Soma  Dual Origins, Sambirano, Elvesia   867.0
# 11993                    Omnom                  Papua New Guinea  1247.0
# 4145                    Domori                 Hacienda Victoria  1672.0
# 10884                    Arete            Puerto Quito, heirloom  1534.0
# 6125         Green Bean to Bar                        Madagascar  1896.0
#
#        ReviewDate Cocoa Percent CompanyLocation  Rating              BeanType  \
# 87         2006.0          0.66           Italy     3.0                 Blend
# 6849       2016.0          0.73          Canada     3.0               Criollo
# 3822       2011.0          0.75          France     3.0               Criollo
# 10418      2006.0          0.62          U.S.A.     3.0                 Blend
# 1505       2013.0           0.7          U.S.A.     3.5               Criollo
# 10510      2012.0           0.7          Canada     2.5                 Blend
# 11993      2014.0           0.7         Iceland     3.0               Criollo
# 4145       2015.0           0.7           Italy     4.0               Criollo
# 10884      2015.0           0.7          U.S.A.     3.0  Forastero (Nacional)
# 6125       2016.0           0.7           Japan     3.0               Criollo
#
#             Broad BeanOrigin
# 87                   Bolivia
# 6849                Tanzania
# 3822              Madagascar
# 10418                Bolivia
# 1505                    Peru
# 10510  Dom. Rep., Madagascar
# 11993       Papua New Guinea
# 4145                 Ecuador
# 10884                Ecuador
# 6125              Madagascar

# %% [markdown]
# #### Задание 7. Показать типы данных для каждого столбца в DataFrame

# %%
df.dtypes
# Out:
# Company (Maker-if known)            object
# Specific Bean Originor Bar Name     object
# REF                                float64
# ReviewDate                         float64
# Cocoa Percent                       object
# CompanyLocation                     object
# Rating                             float64
# BeanType                            object
# Broad BeanOrigin                    object
# dtype: object

# %% [markdown]
# #### Задание 8. Показать информацию о DataFrame, включая количество непропущенных значений, типы данных

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14360 entries, 0 to 14359
# Data columns (total 9 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Company (Maker-if known)         14360 non-null  object
#  1   Specific Bean Originor Bar Name  14360 non-null  object
#  2   REF                              14275 non-null  float64
#  3   ReviewDate                       14280 non-null  float64
#  4   Cocoa Percent                    14288 non-null  object
#  5   CompanyLocation                  14360 non-null  object
#  6   Rating                           14299 non-null  float64
#  7   BeanType                         14360 non-null  object
#  8   Broad BeanOrigin                 14360 non-null  object
# dtypes: float64(3), object(6)
# memory usage: 1009.8+ KB

# %% [markdown]
# #### Задание 9. Показать статистический анализ числовых столбцов, включая среднее, стандартное отклонение, минимум и максимум о DataFrame

# %%
df.describe()
# Out:
#                 REF    ReviewDate        Rating
# count  14275.000000  14280.000000  14299.000000
# mean    1035.708441   2012.324370      3.073502
# std      553.050754      2.927582      0.619286
# min        5.000000   2006.000000      1.750000
# 25%      576.000000   2010.000000      2.750000
# 50%     1069.000000   2013.000000      3.000000
# 75%     1506.000000   2015.000000      3.000000
# max     1952.000000   2017.000000      4.750000

# %% [markdown]
# #### Задание 10. Показать возвращение DataFrame с булевыми значениями, указывающими на пропущенные значения

# %%
df.isna()
# Out:
#        Company (Maker-if known)  Specific Bean Originor Bar Name    REF  \
# 0                         False                            False  False
# 1                         False                            False  False
# 2                         False                            False   True
# 3                         False                            False   True
# 4                         False                            False  False
# ...                         ...                              ...    ...
# 14355                     False                            False  False
# 14356                     False                            False  False
# 14357                     False                            False  False
# 14358                     False                            False  False
# 14359                     False                            False  False
#
#        ReviewDate  Cocoa Percent  CompanyLocation  Rating  BeanType  \
# 0            True          False            False   False     False
# 1           False          False            False   False     False
# 2           False          False            False    True     False
# 3            True          False            False   False     False
# 4            True          False            False    True     False
# ...           ...            ...              ...     ...       ...
# 14355       False          False            False   False     False
# 14356       False          False            False   False     False
# 14357       False          False            False   False     False
# 14358       False          False            False   False     False
# 14359       False          False            False   False     False
#
#        Broad BeanOrigin
# 0                 False
# 1                 False
# 2                 False
# 3                 False
# 4                 False
# ...                 ...
# 14355             False
# 14356             False
# 14357             False
# 14358             False
# 14359             False
#
# [14360 rows x 9 columns]

# %% [markdown]
# #### Задание 11. Заменить пропущенные значения значением value в DataFrame

# %%
df.fillna(24)
# Out:
#       Company (Maker-if known) Specific Bean Originor Bar Name     REF  \
# 0                     A. Morin                     Agua Grande  1876.0
# 1                     A. Morin                           Kpime  1676.0
# 2                     A. Morin                          Atsane    24.0
# 3                     A. Morin                           Akata    24.0
# 4                     A. Morin                          Quilla  1704.0
# ...                        ...                             ...     ...
# 14355                   Zotter                            Peru   647.0
# 14356                   Zotter                           Congo   749.0
# 14357                   Zotter                    Kerala State   749.0
# 14358                   Zotter                    Kerala State   781.0
# 14359                   Zotter              Brazil, Mitzi Blue   486.0
#
#        ReviewDate Cocoa Percent CompanyLocation  Rating   BeanType  \
# 0            24.0          0.63          France    3.75    Criollo
# 1          2015.0           0.7          France    2.75    Criollo
# 2          2015.0           0.7          France   24.00    Criollo
# 3            24.0           0.7          France    3.00    Criollo
# 4            24.0           0.7          France   24.00    Criollo
# ...           ...           ...             ...     ...        ...
# 14355      2011.0           0.7         Austria    2.00    Criollo
# 14356      2011.0          0.65         Austria    3.00  Forastero
# 14357      2011.0          0.65         Austria    3.50  Forastero
# 14358      2011.0          0.62         Austria    2.00    Criollo
# 14359      2010.0          0.65         Austria    2.75    Criollo
#
#       Broad BeanOrigin
# 0             Sao Tome
# 1                 Togo
# 2                 Togo
# 3                 Togo
# 4                 Peru
# ...                ...
# 14355             Peru
# 14356            Congo
# 14357            India
# 14358            India
# 14359           Brazil
#
# [14360 rows x 9 columns]

# %% [markdown]
# #### Задание 12. Заменить пропущенные значения значением среднего в DataFrame

# %% [markdown]
# Ссылка на Colab: https://colab.research.google.com/drive/1qgf1xHH7dmIk7Jn6eXG5km6qvh906Df6?usp=sharing

# %%
# df.fillna(df.mean())

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Задание 13. Заменить пропущенные значения значением медианы в DataFrame

# %%
#df.fillna(df.median())

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Задание 14. Заменить пропущенные значения значением максимальным в DataFrame

# %%
# df.fillna(df.max())

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Задание 15. Заменить пропущенные значения значением минимальным в DataFrame

# %%
# df.fillna(df.min())

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Задание 16. Показать количество уникальных значений в каждом столбце в DataFrame

# %%
df.nunique()
# Out:
# Company (Maker-if known)            416
# Specific Bean Originor Bar Name    1038
# REF                                 440
# ReviewDate                           12
# CocoaPercent                         45
# CompanyLocation                      60
# Rating                                9
# BeanType                             40
# Broad BeanOrigin                     99
# dtype: int64

# %% [markdown]
# #### Задание 17. Подсчитать количество вхождений каждого уникального значения в столбце в DataFrame

# %%
df.value_counts()
# Out:
# Company (Maker-if known)            Specific Bean Originor Bar Name  REF     ReviewDate  CocoaPercent  CompanyLocation  Rating  BeanType    Broad BeanOrigin
# A. Morin                            Carenero                         1315.0  2014.0      0.70          France           3.50    Criollo     Venezuela           8
# Original Hawaiin Chocolate Factory  Hawai'i, Kona Grand Cru E.       316.0   2009.0      0.60          U.S.A.           3.00    Criollo     Hawaii              8
# Obolo                               Pangoa, w/ nibs                  1638.0  2015.0      0.70          Chile            2.75    Criollo     Peru                8
# Ocelot                              Piura                            1558.0  2015.0      0.75          Scotland         3.00    Criollo     Peru                8
#                                     Virunga                          1558.0  2015.0      0.70          Scotland         2.75    Forastero   Congo               8
#                                                                                                                                                                ..
# Duffy's                             Chuno, Xoco                      1331.0  2014.0      0.70          U.K.             3.00    Criollo     Nicaragua           8
#                                     Indio Rojo, Xoco                 623.0   2011.0      0.72          U.K.             2.75    Criollo     Honduras            8
#                                     Nicaliso, Xoco                   697.0   2011.0      0.71          U.K.             2.50    Criollo     Nicaragua           8
#                                     Rico Rugoso, Xoco                1331.0  2014.0      0.76          U.K.             3.50    Criollo     Nicaragua           8
# twenty-four blackbirds              Madagascar                       1235.0  2014.0      0.75          U.S.A.           3.00    Trinitario  Madagascar          8
# Name: count, Length: 875, dtype: int64

# %% [markdown]
# #### Задание 18. Удалить строки с пропущенными значениями в DataFrame

# %%
df.dropna()
# Out:
#       Company (Maker-if known) Specific Bean Originor Bar Name     REF  \
# 1                     A. Morin                           Kpime  1676.0
# 5                     A. Morin                        Carenero  1315.0
# 22                    A. Morin                            Peru   797.0
# 23                      Acalli         Chulucanas, El Platanal  1462.0
# 24                      Acalli               Tumbes, Norandino  1470.0
# ...                        ...                             ...     ...
# 14355                   Zotter                            Peru   647.0
# 14356                   Zotter                           Congo   749.0
# 14357                   Zotter                    Kerala State   749.0
# 14358                   Zotter                    Kerala State   781.0
# 14359                   Zotter              Brazil, Mitzi Blue   486.0
#
#        ReviewDate Cocoa Percent CompanyLocation  Rating   BeanType  \
# 1          2015.0           0.7          France    2.75    Criollo
# 5          2014.0           0.7          France    3.50    Criollo
# 22         2012.0          0.63          France    3.00    Criollo
# 23         2015.0           0.7          U.S.A.    3.50    Criollo
# 24         2015.0           0.7          U.S.A.    3.50    Criollo
# ...           ...           ...             ...     ...        ...
# 14355      2011.0           0.7         Austria    2.00    Criollo
# 14356      2011.0          0.65         Austria    3.00  Forastero
# 14357      2011.0          0.65         Austria    3.50  Forastero
# 14358      2011.0          0.62         Austria    2.00    Criollo
# 14359      2010.0          0.65         Austria    2.75    Criollo
#
#       Broad BeanOrigin
# 1                 Togo
# 5            Venezuela
# 22                Peru
# 23                Peru
# 24                Peru
# ...                ...
# 14355             Peru
# 14356            Congo
# 14357            India
# 14358            India
# 14359           Brazil
#
# [14174 rows x 9 columns]

# %% [markdown]
# #### Задание 19. Показать булевы значения, указывающие на дубликаты строк в DataFrame

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 14355     True
# 14356     True
# 14357     True
# 14358     True
# 14359     True
# Length: 14360, dtype: bool

# %% [markdown]
# #### Задание 20. Удалить дубликаты строк из DataFrame

# %%
df.drop_duplicates()
# Out:
#       Company (Maker-if known) Specific Bean Originor Bar Name     REF  \
# 0                     A. Morin                     Agua Grande  1876.0
# 1                     A. Morin                           Kpime  1676.0
# 2                     A. Morin                          Atsane     NaN
# 3                     A. Morin                           Akata     NaN
# 4                     A. Morin                          Quilla  1704.0
# ...                        ...                             ...     ...
# 14325                  Xocolla               Hispaniola, batch  1948.0
# 14326                    Zak's        Papua New Guinea, Batch   1574.0
# 14327                    Zak's      Dominican Republic, Batch   1578.0
# 14328                    Zak's               Madagascar, Batch  1578.0
# 14350                   Zotter                    Huiwani Coop     NaN
#
#        ReviewDate Cocoa Percent CompanyLocation  Rating             BeanType  \
# 0             NaN          0.63          France    3.75              Criollo
# 1          2015.0           0.7          France    2.75              Criollo
# 2          2015.0           0.7          France     NaN              Criollo
# 3             NaN           0.7          France    3.00              Criollo
# 4             NaN           0.7          France     NaN              Criollo
# ...           ...           ...             ...     ...                  ...
# 14325      2017.0           0.7          U.S.A.    4.00              Criollo
# 14326      2015.0           0.7          U.S.A.    3.75              Criollo
# 14327      2015.0           0.7          U.S.A.    2.75              Criollo
# 14328      2015.0           0.7          U.S.A.    3.00           Trinitario
# 14350      2012.0          0.75         Austria    2.75  Criollo, Trinitario
#
#          Broad BeanOrigin
# 0                Sao Tome
# 1                    Togo
# 2                    Togo
# 3                    Togo
# 4                    Peru
# ...                   ...
# 14325  Dominican Republic
# 14326    Papua New Guinea
# 14327   Domincan Republic
# 14328          Madagascar
# 14350    Papua New Guinea
#
# [1938 rows x 9 columns]

# %% [markdown]
# #### Задание 21. Заменить определенные значения в DataFrame на указанные

# %%
df.replace(2015, 2004)
# Out:
#       Company (Maker-if known) Specific Bean Originor Bar Name     REF  \
# 0                     A. Morin                     Agua Grande  1876.0
# 1                     A. Morin                           Kpime  1676.0
# 2                     A. Morin                          Atsane     NaN
# 3                     A. Morin                           Akata     NaN
# 4                     A. Morin                          Quilla  1704.0
# ...                        ...                             ...     ...
# 14355                   Zotter                            Peru   647.0
# 14356                   Zotter                           Congo   749.0
# 14357                   Zotter                    Kerala State   749.0
# 14358                   Zotter                    Kerala State   781.0
# 14359                   Zotter              Brazil, Mitzi Blue   486.0
#
#        ReviewDate Cocoa Percent CompanyLocation  Rating   BeanType  \
# 0             NaN          0.63          France    3.75    Criollo
# 1          2004.0           0.7          France    2.75    Criollo
# 2          2004.0           0.7          France     NaN    Criollo
# 3             NaN           0.7          France    3.00    Criollo
# 4             NaN           0.7          France     NaN    Criollo
# ...           ...           ...             ...     ...        ...
# 14355      2011.0           0.7         Austria    2.00    Criollo
# 14356      2011.0          0.65         Austria    3.00  Forastero
# 14357      2011.0          0.65         Austria    3.50  Forastero
# 14358      2011.0          0.62         Austria    2.00    Criollo
# 14359      2010.0          0.65         Austria    2.75    Criollo
#
#       Broad BeanOrigin
# 0             Sao Tome
# 1                 Togo
# 2                 Togo
# 3                 Togo
# 4                 Peru
# ...                ...
# 14355             Peru
# 14356            Congo
# 14357            India
# 14358            India
# 14359           Brazil
#
# [14360 rows x 9 columns]

# %% [markdown]
# #### Задание 22. Сохранить DataFrame в формат Excel с именем Practice2_dataset.xlsx

# %%
df.to_excel('Practice2_dataset.xlsx')

# %% [markdown]
# #### Задание 23. Сохранить DataFrame в формат CSV с именем Practice2_ dataset.CSV

# %%
df.to_csv('Practice2_dataset.csv')

# %% [markdown]
# #### Задание 24. Сохранить DataFrame в формат JSON с именем Practice2_ dataset.json

# %%
df.to_json('Practice2_dataset.json')
